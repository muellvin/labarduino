# %%
import numpy as np


T_reference = 21.42 + 273.15
R0 = 1
R = 1.26829
T0 = 298.15

B = 1/(1/T_reference-1/T0)*np.log(R/R0)

print(B)
# Out:
# 5830.607688759309

# %%
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit


file_path = 'heating4_83ohm.txt'

# Read numbers from file
with open(file_path, 'r') as file:
    numbers = [float(line.strip()) for line in file]


def exponential_func(x, a, b, c, d):
    return a + b * np.exp(-c * (x-d))

# Generate x values (indices)
x_data = np.arange(8, len(numbers))
y_data = np.array(numbers[8:len(numbers)])

# Fit the exponential function to the data
p0 = [30, -10,0.1,8]
params, covariance = curve_fit(exponential_func, x_data, y_data, p0=p0)

# Extract the fitting parameters
a_fit, b_fit, c_fit, d_fit = params

# Generate y values based on the fitted exponential curve
y_fit = exponential_func(x_data, a_fit, b_fit, c_fit, d_fit)

# Plot the original data and the fitted curve
#plt.plot(x_data, y_data, label='Original Data', marker='o')
plt.plot(x_data, y_fit, label=f'Fitted Exponential: time constant ={(1/c_fit):.2f}', linestyle='--')
#plt.plot(x_data, exponential_func(x_data, p0[0],p0[1],p0[2],p0[3]), label=f'Fitted Exponential: a={a_fit:.2f}, b={b_fit:.2f}', linestyle=':')

# Plot the numbers
plt.plot(numbers, label='Measurement')
plt.xlabel('time [s]')
plt.ylabel('T [°C]')
plt.title('Heating with 83 Ohm resistor')
plt.grid(True)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit


file_path = '2pointcontrol.txt'

# Read numbers from file
with open(file_path, 'r') as file:
    numbers = [float(line.strip()) for line in file]

plt.plot(numbers, label='Measurement')
plt.xlabel('time [s]')
plt.ylabel('T [°C]')
plt.title('Heating with 83 Ohm resistor')
plt.grid(True)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# Replace 'your_file.txt' with the path to your file
file_path = 'dc_vs_rpm.txt'

# Read x and y values from the file
x_values = []
y_values = []

with open(file_path, 'r') as file:
    for line in file:
        x, y = map(float, line.strip().split())
        y_values.append(x)
        x_values.append(y*100/255)


# Plot y vs x
plt.scatter(x_values, y_values, label='Data Points')
plt.xlabel('X Values')
plt.ylabel('Y Values')
plt.title('Scatter Plot of Y vs X')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# [0.0, 1.9607843137254901, 3.9215686274509802, 5.882352941176471, 7.8431372549019605, 9.803921568627452, 11.764705882352942, 13.72549019607843, 15.686274509803921, 17.647058823529413, 19.607843137254903, 21.568627450980394, 23.529411764705884, 25.49019607843137, 27.45098039215686, 29.41176470588235, 31.372549019607842, 33.333333333333336, 35.294117647058826, 37.254901960784316, 39.21568627450981, 41.1764705882353, 43.13725490196079, 45.09803921568628, 47.05882352941177, 49.01960784313726, 50.98039215686274, 52.94117647058823, 54.90196078431372, 56.86274509803921, 58.8235294117647, 60.78431372549019, 62.745098039215684, 64.70588235294117, 66.66666666666667, 68.62745098039215, 70.58823529411765, 72.54901960784314, 74.50980392156863, 76.47058823529412, 78.43137254901961, 80.3921568627451, 82.3529411764706, 84.31372549019608, 86.27450980392157, 88.23529411764706, 90.19607843137256, 92.15686274509804, 94.11764705882354, 96.07843137254902, 98.03921568627452, 100.0]
